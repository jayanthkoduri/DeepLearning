# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch.autograd import Variable
import torch.nn.functional as F

import numpy as np
import random
from scipy.special import expit

import sys
import os
import json
import re
import pickle
import time

# %%
from collections import Counter
import json
import re

def preprocess_text_data():
    file_path = 'data/'

    word_frequency = Counter()

    with open(file_path + 'training_label.json', 'r') as file_handle:
        data = json.load(file_handle)

    
    for entry in data:
        for sentence in entry['caption']:
            words_in_sentence = re.sub('[.!,;?]', ' ', sentence).lower().split()
            word_frequency.update(words_in_sentence)

    filtered_word_dict = {word: freq for word, freq in word_frequency.items() if freq > 4}
    special_tokens = [('<PAD>', 0), ('<SOS>', 1), ('<EOS>', 2), ('<UNK>', 3)]
    index_to_word = {index + len(special_tokens): word for index, word in enumerate(filtered_word_dict)}
    word_to_index = {word: index + len(special_tokens) for index, word in enumerate(filtered_word_dict)}
    for token, index in special_tokens:
        index_to_word[index] = token
        word_to_index[token] = index

    return index_to_word, word_to_index, filtered_word_dict

# %%
def encode_sentence(input_text, vocabulary, word_to_index):
    tokens = re.sub(r'[.!,;?]', ' ', input_text).split()
    encoded_text = [word_to_index.get(token, 3) for token in tokens]
    encoded_text = [1] + encoded_text + [2]
    return encoded_text

# %%
def annotate(file_name, vocab, index_map):
    full_path = f'data/{file_name}'
    processed_captions = []
    with open(full_path, 'r') as json_file:
        data_labels = json.load(json_file)

    for item in data_labels:
        for text in item['caption']:
            transformed_text = encode_sentence(text, vocab, index_map)
            processed_captions.append((item['id'], transformed_text))

    return processed_captions

# %%
def avi(directory_path):
    loaded_data = {}
    data_folder_path = 'data/' + directory_path
    numpy_files = os.listdir(data_folder_path)
    file_index = 0
    for numpy_file in numpy_files:
        print(f"Processing file number: {file_index}")
        file_index += 1
        data = np.load(os.path.join(data_folder_path, numpy_file))
        key_name = numpy_file.rsplit('.npy', 1)[0]
        loaded_data[key_name] = data
    return loaded_data

# %%
def prepare_batch(batch_data):
    batch_data.sort(key=lambda item: len(item[1]), reverse=True)
    avi_list, caption_list = zip(*batch_data)
    avi_tensor = torch.stack(avi_list, dim=0)
    caption_lengths = list(map(len, caption_list))
    max_length = max(caption_lengths)
    caption_targets = torch.zeros(len(caption_list), max_length).long()

    for index, caption in enumerate(caption_list):
        caption_end = caption_lengths[index]
        caption_targets[index, :caption_end] = torch.LongTensor(caption[:caption_end])

    return avi_tensor, caption_targets, caption_lengths

# %%
class TrainingData(Dataset):
    def __init__(self, label_file, files_dir, word_dict, w2i):
        self.label_file = label_file
        self.files_dir = files_dir
        self.word_dict = word_dict
        self.w2i = w2i
        self.avi = avi(label_file)
        self.data_pair = annotate(files_dir, word_dict, w2i)
        
    def __len__(self):
        return len(self.data_pair)
    
    def __getitem__(self, index):
        if index >= self.__len__():
            raise IndexError("Index exceeds dataset size.")
        
        video_name, text = self.data_pair[index]
        video_tensor = torch.Tensor(self.avi[video_name])
        video_tensor += torch.rand(video_tensor.size()) * 0.2 
        text_tensor = torch.tensor(text, dtype=torch.long)
        
        return video_tensor, text_tensor

# %%
class TestingData(Dataset):
    def __init__(self, test_data_path):
        self.dataset_entries = []
        for filename in os.listdir(test_data_path):
            identifier = filename.split('.npy')[0]
            data = np.load(os.path.join(test_data_path, filename))
            self.dataset_entries.append([identifier, data])
            
    def __len__(self):
        return len(self.dataset_entries)
    
    def __getitem__(self, index):
        if index >= len(self):
            raise IndexError("Index out of range")
        return self.dataset_entries[index]

# %%
class Attention(nn.Module):
    def __init__(self, hidden_size):
        super(Attention, self).__init__()
        
        self.hidden_size = hidden_size
        self.attention_layer1 = nn.Linear(2*hidden_size, hidden_size)
        self.attention_layer2 = nn.Linear(hidden_size, hidden_size)
        self.attention_layer3 = nn.Linear(hidden_size, hidden_size)
        self.attention_layer4 = nn.Linear(hidden_size, hidden_size)
        self.compute_weight = nn.Linear(hidden_size, 1, bias=False)

    def forward(self, hidden_state, encoder_outputs):
        batch_size, seq_len, hidden_dim = encoder_outputs.size()
        hidden_state_expanded = hidden_state.view(batch_size, 1, hidden_dim).repeat(1, seq_len, 1)
        combined_inputs = torch.cat((encoder_outputs, hidden_state_expanded), 2).view(-1, 2*self.hidden_size)

        attn_hidden = self.attention_layer1(combined_inputs)
        attn_hidden = self.attention_layer2(attn_hidden)
        attn_hidden = self.attention_layer3(attn_hidden)
        attn_hidden = self.attention_layer4(attn_hidden)
        weights = self.compute_weight(attn_hidden)
        weights = weights.view(batch_size, seq_len)
        weights_normalized = F.softmax(weights, dim=1)
        context_vector = torch.bmm(weights_normalized.unsqueeze(1), encoder_outputs).squeeze(1)
        
        return context_vector

# %%
class EncoderLSTM(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.embedding_layer = nn.Linear(4096, 512)
        self.dropout_layer = nn.Dropout(0.33)
        self.lstm_layer = nn.LSTM(512, 512, batch_first=True)

    def forward(self, x):
        batch_size, sequence_length, features = x.shape    
        x = x.reshape(-1, features)
        x = self.embedding_layer(x)
        x = self.dropout_layer(x)
        x = x.reshape(batch_size, sequence_length, 512)

        lstm_output, (hidden_state, cell_state) = self.lstm_layer(x)
        return lstm_output, hidden_state

# %%
class DecoderLSTM(nn.Module):
    def __init__(self, hidden_size, output_size, vocab_size, word_dim, dropout_percentage=0.33):
        super(DecoderLSTM, self).__init__()
        self.hidden_size = 512
        self.output_size = output_size
        self.vocab_size = vocab_size
        self.word_dim = word_dim
        self.embedding = nn.Embedding(output_size, 1024)
        self.dropout = nn.Dropout(dropout_percentage)
        self.lstm = nn.LSTM(hidden_size + word_dim, hidden_size, batch_first=True)
        self.attention = Attention(hidden_size)
        self.fc = nn.Linear(hidden_size, output_size)  # Renamed to fc for clarity

    def forward(self, encoder_hidden_state_last, encoder_output, targets=None, mode='train', tr_steps=None):
        _, batch_size, _ = encoder_hidden_state_last.size()
        decoder_hidden_state = encoder_hidden_state_last
        decoder_context = torch.zeros(decoder_hidden_state.size()).cuda()
        decoder_input_word = Variable(torch.ones(batch_size, 1)).long().cuda()
        sequence_log_probabilities = []
        sequence_predictions = []

        targets_embedded = self.embedding(targets)
        _, sequence_length, _ = targets_embedded.size()

        for i in range(sequence_length - 1):
            teacher_forcing_threshold = self.calculate_teacher_forcing_ratio(tr_steps)
            if random.uniform(0.05, 0.995) > teacher_forcing_threshold:
                input_word = targets_embedded[:, i]
            else:
                input_word = self.embedding(decoder_input_word).squeeze(1)

            context_vector = self.attention(decoder_hidden_state, encoder_output)
            lstm_input = torch.cat([input_word, context_vector], dim=1).unsqueeze(1)
            lstm_output, (decoder_hidden_state, decoder_context) = self.lstm(lstm_input, (decoder_hidden_state, decoder_context))
           
            log_probability = self.fc(lstm_output.squeeze(1))
            sequence_log_probabilities.append(log_probability.unsqueeze(1))
            decoder_input_word = log_probability.max(1)[1]

        sequence_log_probabilities = torch.cat(sequence_log_probabilities, dim=1)
        sequence_predictions = sequence_log_probabilities.max(2)[1]

        return sequence_log_probabilities, sequence_predictions

    def infer(self, encoder_hidden_state_last, encoder_output):
        _, batch_size, _ = encoder_hidden_state_last.size()
        decoder_hidden_state = encoder_hidden_state_last
        decoder_input_word = Variable(torch.ones(batch_size, 1)).long()
        decoder_context = torch.zeros(decoder_hidden_state.size())
        sequence_log_probabilities = []
        sequence_predictions = []
        predicted_sequence_length = 28

        for i in range(predicted_sequence_length - 1):
            input_word = self.embedding(decoder_input_word).squeeze(1)
            context_vector = self.attention(decoder_hidden_state, encoder_output)
            lstm_input = torch.cat([input_word, context_vector], dim=1).unsqueeze(1)
            lstm_output, (decoder_hidden_state, decoder_context) = self.lstm(lstm_input, (decoder_hidden_state, decoder_context))
            
            log_probability = self.fc(lstm_output.squeeze(1))
            sequence_log_probabilities.append(log_probability.unsqueeze(1))
            decoder_input_word = log_probability.max(2)[1]

        sequence_log_probabilities = torch.cat(sequence_log_probabilities, dim=1)
        sequence_predictions = sequence_log_probabilities.max(2)[1]

        return sequence_log_probabilities, sequence_predictions

    def calculate_teacher_forcing_ratio(self, training_steps):
        return expit(training_steps / 20 + 0.85)

# %%
class Models(nn.Module):
    def __init__(self, encoder, decoder):
        super(Models, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
    def forward(self, avi_feat, mode, target_sentences=None, tr_steps=None):
        encoder_outputs, encoder_hidden_state_last = self.encoder(avi_feat)
        if mode == 'train':
            seq_logProb, seq_predictions = self.decoder(encoder_hidden_state_last = encoder_hidden_state_last, encoder_output = encoder_outputs,
                targets = target_sentences, mode = mode, tr_steps=tr_steps)
        elif mode == 'inference':
            seq_logProb, seq_predictions = self.decoder.infer(encoder_last_hidden_state=encoder_last_hidden_state, encoder_output=encoder_outputs)
        return seq_logProb, seq_predictions

# %%
def calculate_loss(loss_fn, predictions, targets, lengths):
    device = predictions.device
    batch_size = predictions.shape[0]
    
    # Ensure predictions are on the correct device and are of floating point type
    concatenated_predictions = torch.Tensor().to(device).float()  # This should already be the case
    
    # Ensure targets are on the correct device and are of integer type, suitable for cross_entropy
    concatenated_targets = torch.LongTensor().to(device)  # Targets must be integers
    
    for index in range(batch_size):
        sequence_length = lengths[index] - 1
        sliced_prediction = predictions[index, :sequence_length]
        sliced_target = targets[index, :sequence_length]
        concatenated_predictions = torch.cat((concatenated_predictions, sliced_prediction), dim=0)
        concatenated_targets = torch.cat((concatenated_targets, sliced_target.type(torch.long)), dim=0)  # Ensure targets are long
    
    total_loss = loss_fn(concatenated_predictions, concatenated_targets)
    avg_loss = total_loss / batch_size
    return avg_loss

# %%
def minibatch(data):
    data.sort(key=lambda x: len(x[1]), reverse=True)
    videos, captions = zip(*data)
    video_tensor = torch.stack(videos, dim=0)
    cap_lengths = [len(cap) for cap in captions]
    cap_tensor = torch.zeros(len(captions), max(cap_lengths), dtype=torch.long)
    for idx, cap in enumerate(captions):
        length = cap_lengths[idx]
        cap_tensor[idx, :length] = torch.tensor(cap[:length], dtype=torch.long)
    return video_tensor, cap_tensor, cap_lengths

# %%
def train(model, epoch, loss_fn, parameters, optimizer, train_loader):
    model.train()
    for batch_idx, batch in enumerate(train_loader):
        avi_feats, ground_truths, lengths = batch
        avi_feats, ground_truths = Variable(avi_feats).cuda(), Variable(ground_truths).cuda()
        optimizer.zero_grad()
        seq_logProb, seq_predictions = model(avi_feats, target_sentences=ground_truths, mode='train', tr_steps=epoch)
        ground_truths = ground_truths[:, 1:]
        loss = calculate_loss(loss_fn, seq_logProb, ground_truths, lengths)
        print('Batch - ', batch_idx, ' Loss - ', loss)
        loss.backward()
        optimizer.step()

    loss_value = loss.item()
    return loss_value

# %%
def evaluate_model(data_loader, neural_model, index_to_word):
    neural_model.eval()
    predictions_list = []

    for batch_index, data_batch in enumerate(data_loader):
        ids, features = data_batch
        features_gpu = features.cuda()
        _, processed_features = ids, Variable(features_gpu).float()
        _, predicted_sequences = neural_model(processed_features, mode='inference')
        decoded_predictions = [[index_to_word[token.item()] if index_to_word[token.item()] != '<UNK>' else 'something' for token in sequence] for sequence in predicted_sequences]
        sentences = [' '.join(sequence).split('<EOS>')[0] for sequence in decoded_predictions]
        id_sentence_pairs = zip(ids, sentences)
        for pair in id_sentence_pairs:
            predictions_list.append(pair)
            
    return predictions_list

# %%
def main():

    index_to_word, word_to_index, word_dict = preprocess_text_data()
    with open('i2w.pickle', 'wb') as file:
        pickle.dump(index_to_word, file, protocol=pickle.HIGHEST_PROTOCOL)
    label_directory = 'training_data/feat'
    files_directory = 'training_label.json'
    training_data = TrainingData(label_directory, files_directory, word_dict, word_to_index)
    dataloader = DataLoader(dataset=training_data, batch_size=64, shuffle=True, num_workers=8, collate_fn=minibatch)
    
    num_epochs = 20
    dropout_rate = 0.33

    encoder = EncoderLSTM()
    decoder = DecoderLSTM(512, len(index_to_word) + 4, len(index_to_word) + 4, 1024, dropout_rate)
    model = Models(encoder=encoder, decoder=decoder)

    model.cuda()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0001)
    training_losses = []

    for epoch in range(num_epochs):
        epoch_loss = train(model, epoch + 1, criterion, model.parameters(), optimizer, dataloader)
        training_losses.append(epoch_loss)
    
    torch.save(model, "SavedModel/model.h5")
    print("Completed Training")

if __name__ == "__main__":
    main()
# Out:
# Processing file number: 0
# Processing file number: 1
# Processing file number: 2
# Processing file number: 3
# Processing file number: 4
# Processing file number: 5
# Processing file number: 6
# Processing file number: 7
# Processing file number: 8
# Processing file number: 9
# Processing file number: 10
# Processing file number: 11
# Processing file number: 12
# Processing file number: 13
# Processing file number: 14
# Processing file number: 1094
# Processing file number: 1095
# Processing file number: 1096
# Processing file number: 1097
# Processing file number: 1098
# Processing file number: 1099
# Processing file number: 1100
# Processing file number: 1101
# Processing file number: 1102
# Processing file number: 1103
# Processing file number: 1104
# Processing file number: 1105
# Processing file number: 1106
# Processing file number: 1107
# Processing file number: 1108
# Processing file number: 1109
# Processing file number: 1110
# Processing file number: 1111
# Processing file number: 1112
# Processing file number: 1113
# Processing file number: 1114
# Processing file number: 1115
# Processing file number: 1116
# Processing file number: 1117
# Processing file number: 1118
# Processing file number: 1119
# Processing file number: 1120
# Processing file number: 1121
# Processing file number: 1122
# Processing file number: 1123
# Processing file number: 1124
# Processing file number: 1125
# Processing file number: 1126
# Processing file number: 1127
# Processing file number: 1128
# Processing file number: 1129
# Processing file number: 1130
# Processing file number: 1131
# Processing file number: 1132
# Processing file number: 1133
# Processing file number: 1134
# Processing file number: 1135
# Processing file number: 1136
# Processing file number: 1137
# Processing file number: 1138
# Processing file number: 1139
# Processing file number: 1140
# Processing file number: 1141
# Processing file number: 1142
# Processing file number: 1143
# Processing file number: 1144
# Processing file number: 1145
# Processing file number: 1146
# Processing file number: 1147
# Processing file number: 1148
# Processing file number: 1149
# Processing file number: 1150
# Processing file number: 1151
# Processing file number: 1152
# Processing file number: 1153
# Processing file number: 1154
# Processing file number: 1155
# Processing file number: 1156
# Processing file number: 1157
# Processing file number: 1158
# Processing file number: 1159
# Processing file number: 1160
# Processing file number: 1161
# Processing file number: 1162
# Processing file number: 1163
# Processing file number: 1164
# Processing file number: 1165
# Processing file number: 1166
# Processing file number: 1167
# Processing file number: 1168
# Processing file number: 1169
# Processing file number: 1170
# Processing file number: 1171
# Processing file number: 1172
# Processing file number: 1173
# Processing file number: 1174
# Processing file number: 1175
# Processing file number: 1176
# Processing file number: 1177
# Processing file number: 1178
# Processing file number: 1179
# Processing file number: 1180
# Processing file number: 1181
# Processing file number: 1182
# Processing file number: 1183
# Processing file number: 1184
# Processing file number: 1185
# Processing file number: 1186
# Processing file number: 1187
# Processing file number: 1188
# Processing file number: 1189
# Processing file number: 1190
# Processing file number: 1191
# Processing file number: 1192
# Processing file number: 1193
# Processing file number: 1194
# Processing file number: 1195
# Processing file number: 1196
# Processing file number: 1197
# Processing file number: 1198
# Processing file number: 1199
# Processing file number: 1200
# Processing file number: 1201
# Processing file number: 1202
# Processing file number: 1203
# Processing file number: 1204
# Processing file number: 1205
# Processing file number: 1206
# Processing file number: 1207
# Processing file number: 1208
# Processing file number: 1209
# Processing file number: 1210
# Processing file number: 1211
# Processing file number: 1212
# Processing file number: 1213
# Processing file number: 1214
# Processing file number: 1215
# Processing file number: 1216
# Processing file number: 1217
# Processing file number: 1218
# Processing file number: 1219
# Processing file number: 1220
# Processing file number: 1221
# Processing file number: 1222
# Processing file number: 1223
# Processing file number: 1224
# Processing file number: 1225
# Processing file number: 1226
# Processing file number: 1227
# Processing file number: 1228
# Processing file number: 1229
# Processing file number: 1230
# Processing file number: 1231
# Processing file number: 1232
# Processing file number: 1233
# Processing file number: 1234
# Processing file number: 1235
# Processing file number: 1236
# Processing file number: 1237
# Processing file number: 1238
# Processing file number: 1239
# Processing file number: 1240
# Processing file number: 1241
# Processing file number: 1242
# Processing file number: 1243
# Processing file number: 1244
# Processing file number: 1245
# Processing file number: 1246
# Processing file number: 1247
# Processing file number: 1248
# Processing file number: 1249
# Processing file number: 1250
# Processing file number: 1251
# Processing file number: 1252
# Processing file number: 1253
# Processing file number: 1254
# Processing file number: 1255
# Processing file number: 1256
# Processing file number: 1257
# Processing file number: 1258
# Processing file number: 1259
# Processing file number: 1260
# Processing file number: 1261
# Processing file number: 1262
# Processing file number: 1263
# Processing file number: 1264
# Processing file number: 1265
# Processing file number: 1266
# Processing file number: 1267
# Processing file number: 1268
# Processing file number: 1269
# Processing file number: 1270
# Processing file number: 1271
# Processing file number: 1272
# Processing file number: 1273
# Processing file number: 1274
# Processing file number: 1275
# Processing file number: 1276
# Processing file number: 1277
# Processing file number: 1278
# Processing file number: 1279
# Processing file number: 1280
# Processing file number: 1281
# Processing file number: 1282
# Processing file number: 1283
# Processing file number: 1284
# Processing file number: 1285
# Processing file number: 1286
# Processing file number: 1287
# Processing file number: 1288
# Processing file number: 1289
# Processing file number: 1290
# Processing file number: 1291
# Processing file number: 1292
# Processing file number: 1293
# Processing file number: 1294
# Processing file number: 1295
# Processing file number: 1296
# Processing file number: 1297
# Processing file number: 1298
# Processing file number: 1299
# Processing file number: 1300
# Processing file number: 1301
# Processing file number: 1302
# Processing file number: 1303
# Processing file number: 1304
# Processing file number: 1305
# Processing file number: 1306
# Processing file number: 1307
# Processing file number: 1308
# Processing file number: 1309
# Processing file number: 1310
# Processing file number: 1311
# Processing file number: 1312
# Processing file number: 1313
# Processing file number: 1314
# Processing file number: 1315
# Processing file number: 1316
# Processing file number: 1317
# Processing file number: 1318
# Processing file number: 1319
# Processing file number: 1320
# Processing file number: 1321
# Processing file number: 1322
# Processing file number: 1323
# Processing file number: 1324
# Processing file number: 1325
# Processing file number: 1326
# Processing file number: 1327
# Processing file number: 1328
# Processing file number: 1329
# Processing file number: 1330
# Processing file number: 1331
# Processing file number: 1332
# Processing file number: 1333
# Processing file number: 1334
# Processing file number: 1335
# Processing file number: 1336
# Processing file number: 1337
# Processing file number: 1338
# Processing file number: 1339
# Processing file number: 1340
# Processing file number: 1341
# Processing file number: 1342
# Processing file number: 1343
# Processing file number: 1344
# Processing file number: 1345
# Processing file number: 1346
# Processing file number: 1347
# Processing file number: 1348
# Processing file number: 1349
# Processing file number: 1350
# Processing file number: 1351
# Processing file number: 1352
# Processing file number: 1353
# Processing file number: 1354
# Processing file number: 1355
# Processing file number: 1356
# Processing file number: 1357
# Processing file number: 1358
# Processing file number: 1359
# Processing file number: 1360
# Processing file number: 1361
# Processing file number: 1362
# Processing file number: 1363
# Processing file number: 1364
# Processing file number: 1365
# Processing file number: 1366
# Processing file number: 1367
# Processing file number: 1368
# Processing file number: 1369
# Processing file number: 1370
# Processing file number: 1371
# Processing file number: 1372
# Processing file number: 1373
# Processing file number: 1374
# Processing file number: 1375
# Processing file number: 1376
# Processing file number: 1377
# Processing file number: 1378
# Processing file number: 1379
# Processing file number: 1380
# Processing file number: 1381
# Processing file number: 1382
# Processing file number: 1383
# Processing file number: 1384
# Processing file number: 1385
# Processing file number: 1386
# Processing file number: 1387
# Processing file number: 1388
# Processing file number: 1389
# Processing file number: 1390
# Processing file number: 1391
# Processing file number: 1392
# Processing file number: 1393
# Processing file number: 1394
# Processing file number: 1395
# Processing file number: 1396
# Processing file number: 1397
# Processing file number: 1398
# Processing file number: 1399
# Processing file number: 1400
# Processing file number: 1401
# Processing file number: 1402
# Processing file number: 1403
# Processing file number: 1404
# Processing file number: 1405
# Processing file number: 1406
# Processing file number: 1407
# Processing file number: 1408
# Processing file number: 1409
# Processing file number: 1410
# Processing file number: 1411
# Processing file number: 1412
# Processing file number: 1413
# Processing file number: 1414
# Processing file number: 1415
# Processing file number: 1416
# Processing file number: 1417
# Processing file number: 1418
# Processing file number: 1419
# Processing file number: 1420
# Processing file number: 1421
# Processing file number: 1422
# Processing file number: 1423
# Processing file number: 1424
# Processing file number: 1425
# Processing file number: 1426
# Processing file number: 1427
# Processing file number: 1428
# Processing file number: 1429
# Processing file number: 1430
# Processing file number: 1431
# Processing file number: 1432
# Processing file number: 1433
# Processing file number: 1434
# Processing file number: 1435
# Processing file number: 1436
# Processing file number: 1437
# Processing file number: 1438
# Processing file number: 1439
# Processing file number: 1440
# Processing file number: 1441
# Processing file number: 1442
# Processing file number: 1443
# Processing file number: 1444
# Processing file number: 1445
# Processing file number: 1446
# Processing file number: 1447
# Processing file number: 1448
# Processing file number: 1449
# /local_scratch/pbs.2064158.pbs02/ipykernel_3213735/1687723406.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cap_tensor[idx, :length] = torch.tensor(cap[:length], dtype=torch.long)
# /local_scratch/pbs.2064158.pbs02/ipykernel_3213735/1687723406.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cap_tensor[idx, :length] = torch.tensor(cap[:length], dtype=torch.long)
# /local_scratch/pbs.2064158.pbs02/ipykernel_3213735/1687723406.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cap_tensor[idx, :length] = torch.tensor(cap[:length], dtype=torch.long)
# /local_scratch/pbs.2064158.pbs02/ipykernel_3213735/1687723406.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cap_tensor[idx, :length] = torch.tensor(cap[:length], dtype=torch.long)
# /local_scratch/pbs.2064158.pbs02/ipykernel_3213735/1687723406.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cap_tensor[idx, :length] = torch.tensor(cap[:length], dtype=torch.long)
# /local_scratch/pbs.2064158.pbs02/ipykernel_3213735/1687723406.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cap_tensor[idx, :length] = torch.tensor(cap[:length], dtype=torch.long)
# /local_scratch/pbs.2064158.pbs02/ipykernel_3213735/1687723406.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cap_tensor[idx, :length] = torch.tensor(cap[:length], dtype=torch.long)
# /local_scratch/pbs.2064158.pbs02/ipykernel_3213735/1687723406.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cap_tensor[idx, :length] = torch.tensor(cap[:length], dtype=torch.long)
# Batch -  0  Loss -  tensor(0.1203, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  1  Loss -  tensor(0.1194, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  2  Loss -  tensor(0.1183, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  3  Loss -  tensor(0.1176, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  4  Loss -  tensor(0.1169, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  5  Loss -  tensor(0.1151, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -
device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  296  Loss -  tensor(0.0351, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  297  Loss -  tensor(0.0329, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  298  Loss -  tensor(0.0354, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  299  Loss -  tensor(0.0359, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  300  Loss -  tensor(0.0347, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  301  Loss -  tensor(0.0393, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  302  Loss -  tensor(0.0303, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  303  Loss -  tensor(0.0354, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  304  Loss -  tensor(0.0317, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  305  Loss -  tensor(0.0359, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  306  Loss -  tensor(0.0341, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  307  Loss -  tensor(0.0344, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  308  Loss -  tensor(0.0329, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  309  Loss -  tensor(0.0388, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  310  Loss -  tensor(0.0335, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  311  Loss -  tensor(0.0382, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  312  Loss -  tensor(0.0364, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  313  Loss -  tensor(0.0419, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  314  Loss -  tensor(0.0373, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  315  Loss -  tensor(0.0320, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  316  Loss -  tensor(0.0352, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  317  Loss -  tensor(0.0320, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  318  Loss -  tensor(0.0354, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  319  Loss -  tensor(0.0320, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  320  Loss -  tensor(0.0325, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  321  Loss -  tensor(0.0347, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  322  Loss -  tensor(0.0308, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  323  Loss -  tensor(0.0355, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  324  Loss -  tensor(0.0376, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  325  Loss -  tensor(0.0341, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  326  Loss -  tensor(0.0321, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  327  Loss -  tensor(0.0317, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  328  Loss -  tensor(0.0366, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  329  Loss -  tensor(0.0385, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  330  Loss -  tensor(0.0408, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  331  Loss -  tensor(0.0340, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  332  Loss -  tensor(0.0339, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  333  Loss -  tensor(0.0396, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  334  Loss -  tensor(0.0333, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  335  Loss -  tensor(0.0375, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  336  Loss -  tensor(0.0332, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  337  Loss -  tensor(0.0377, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  338  Loss -  tensor(0.0312, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  339  Loss -  tensor(0.0382, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  340  Loss -  tensor(0.0394, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  341  Loss -  tensor(0.0357, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  342  Loss -  tensor(0.0356, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  343  Loss -  tensor(0.0402, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  344  Loss -  tensor(0.0366, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  345  Loss -  tensor(0.0388, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  346  Loss -  tensor(0.0363, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  347  Loss -  tensor(0.0338, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  348  Loss -  tensor(0.0357, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  349  Loss -  tensor(0.0332, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  350  Loss -  tensor(0.0378, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  351  Loss -  tensor(0.0384, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  352  Loss -  tensor(0.0405, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  353  Loss -  tensor(0.0400, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  354  Loss -  tensor(0.0382, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  355  Loss -  tensor(0.0365, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  356  Loss -  tensor(0.0384, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  357  Loss -  tensor(0.0359, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  358  Loss -  tensor(0.0405, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  359  Loss -  tensor(0.0401, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  360  Loss -  tensor(0.0364, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  361  Loss -  tensor(0.0378, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  362  Loss -  tensor(0.0349, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  363  Loss -  tensor(0.0327, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  364  Loss -  tensor(0.0374, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  365  Loss -  tensor(0.0304, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  366  Loss -  tensor(0.0375, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  367  Loss -  tensor(0.0327, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  368  Loss -  tensor(0.0321, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  369  Loss -  tensor(0.0369, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  370  Loss -  tensor(0.0365, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  371  Loss -  tensor(0.0385, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  372  Loss -  tensor(0.0338, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  373  Loss -  tensor(0.0333, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  374  Loss -  tensor(0.0349, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  375  Loss -  tensor(0.0363, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  376  Loss -  tensor(0.0323, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  377  Loss -  tensor(0.0345, device='cuda:0', grad_fn=<DivBackward0>)
# Batch -  378  Loss -  tensor(0.0541, device='cuda:0', grad_fn=<DivBackward0>)
# Completed Training
